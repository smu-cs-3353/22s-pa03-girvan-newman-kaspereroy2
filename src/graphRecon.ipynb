# %%
# Patching back together the graph labels with the nodes
import networkx as nx
import matplotlib.pyplot as plt
G= nx.read_graphml('../data/football.graphml') # Reading in the untouched graph

# nx.write_graphml_lxml(G, "output.graphml")

# %%
y = list(G.nodes)
for x in y:
    print(x)
# Out:
# BrighamYoung
# FloridaState
# Iowa
# KansasState
# NewMexico
# TexasTech
# PennState
# SouthernCalifornia
# ArizonaState
# SanDiegoState
# Baylor
# NorthTexas
# NorthernIllinois
# Northwestern
# WesternMichigan
# Wisconsin
# Wyoming
# Auburn
# Akron
# VirginiaTech
# Alabama
# UCLA
# Arizona
# Utah
# ArkansasState
# NorthCarolinaState
# BallState
# Florida
# BoiseState
# BostonCollege
# WestVirginia
# BowlingGreenState
# Michigan
# Virginia
# Buffalo
# Syracuse
# CentralFlorida
# GeorgiaTech
# CentralMichigan
# Purdue
# Colorado
# ColoradoState
# Connecticut
# EasternMichigan
# EastCarolina
# Duke
# FresnoState
# OhioState
# Houston
# Rice
# Idaho
# Washington
# Kansas
# SouthernMethodist
# Kent
# Pittsburgh
# Kentucky
# Louisville
# LouisianaTech
# LouisianaMonroe
# Minnesota
# MiamiOhio
# Vanderbilt
# MiddleTennesseeState
# Illinois
# MississippiState
# Memphis
# Nevada
# Oregon
# NewMexicoState
# SouthCarolina
# Ohio
# IowaState
# SanJoseState
# Nebraska
# SouthernMississippi
# ...

# %%
print(y[0])
# Out:
# BrighamYoung

# %%
print(y)
# Out:
# ['BrighamYoung', 'FloridaState', 'Iowa', 'KansasState', 'NewMexico', 'TexasTech', 'PennState', 'SouthernCalifornia', 'ArizonaState', 'SanDiegoState', 'Baylor', 'NorthTexas', 'NorthernIllinois', 'Northwestern', 'WesternMichigan', 'Wisconsin', 'Wyoming', 'Auburn', 'Akron', 'VirginiaTech', 'Alabama', 'UCLA', 'Arizona', 'Utah', 'ArkansasState', 'NorthCarolinaState', 'BallState', 'Florida', 'BoiseState', 'BostonCollege', 'WestVirginia', 'BowlingGreenState', 'Michigan', 'Virginia', 'Buffalo', 'Syracuse', 'CentralFlorida', 'GeorgiaTech', 'CentralMichigan', 'Purdue', 'Colorado', 'ColoradoState', 'Connecticut', 'EasternMichigan', 'EastCarolina', 'Duke', 'FresnoState', 'OhioState', 'Houston', 'Rice', 'Idaho', 'Washington', 'Kansas', 'SouthernMethodist', 'Kent', 'Pittsburgh', 'Kentucky', 'Louisville', 'LouisianaTech', 'LouisianaMonroe', 'Minnesota', 'MiamiOhio', 'Vanderbilt', 'MiddleTennesseeState', 'Illinois', 'MississippiState', 'Memphis', 'Nevada', 'Oregon', 'NewMexicoState', 'SouthCarolina'
# ...

# %%
Dict = {}
for i in range(len(y)):
    Dict[i] = y[i]
print(Dict)
# Out:
# {0: 'BrighamYoung', 1: 'FloridaState', 2: 'Iowa', 3: 'KansasState', 4: 'NewMexico', 5: 'TexasTech', 6: 'PennState', 7: 'SouthernCalifornia', 8: 'ArizonaState', 9: 'SanDiegoState', 10: 'Baylor', 11: 'NorthTexas', 12: 'NorthernIllinois', 13: 'Northwestern', 14: 'WesternMichigan', 15: 'Wisconsin', 16: 'Wyoming', 17: 'Auburn', 18: 'Akron', 19: 'VirginiaTech', 20: 'Alabama', 21: 'UCLA', 22: 'Arizona', 23: 'Utah', 24: 'ArkansasState', 25: 'NorthCarolinaState', 26: 'BallState', 27: 'Florida', 28: 'BoiseState', 29: 'BostonCollege', 30: 'WestVirginia', 31: 'BowlingGreenState', 32: 'Michigan', 33: 'Virginia', 34: 'Buffalo', 35: 'Syracuse', 36: 'CentralFlorida', 37: 'GeorgiaTech', 38: 'CentralMichigan', 39: 'Purdue', 40: 'Colorado', 41: 'ColoradoState', 42: 'Connecticut', 43: 'EasternMichigan', 44: 'EastCarolina', 45: 'Duke', 46: 'FresnoState', 47: 'OhioState', 48: 'Houston', 49: 'Rice', 50: 'Idaho', 51: 'Washington', 52: 'Kansas', 53: 'SouthernMethodist', 54: 'Kent', 55: 'Pittsburgh', 56: 'Ken
# ...

# %%
from matplotlib.pyplot import figure
#figure(figsize=(20,20), dpi=80)
#nx.draw(G, with_labels=True)
##ax = plt.gca()
#ax.margins(0.0000005)
#plt.axis("off")
#plt.show
# nx.draw(G, labels=labeldict, with_labels = True) USE THIS SORT OF THING TO PRINT LABELS FROM DICT OF ORIGINAL
# Need to check what the type of the list will be

# %%
N = nx.read_graphml('../results/football11.graphml') # Reading in the processed graph

# %%
Dict[0]
# Out:
# 'BrighamYoung'

# %%
y2 = list(N.nodes)
#for x in y2:
   # print(x)

# %%
keys = y2
values = y
dict2 = dict(zip(keys, values))
# print(dict2)

# %%
import numpy as np
plt.figure(3, figsize=(25,25), )
nx.draw(N, with_labels = True, labels = dict2, font_color = "black", node_color="lightsteelblue", edge_color = "gray") #, pos=pos
plt.savefig("graph.png", dpi=80, format="png")
